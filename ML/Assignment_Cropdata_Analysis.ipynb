# %% [markdown]
# <div style="text-align:center;font-size:18px; font-weight:bold;">
# Prof. Ramkrishna More College (Autonomous), Pune-Maharashtra
# Department of Computer Science
# </div>
# <div style="text-align:center;font-size:18px; font-weight:bold;">
# Department of Computer Science
# </div>
# <div style="text-align:center;font-size:18px; font-weight:bold;">
# Instructor : Mr. Sudarshan Lakhdive
# </div>

# %% [markdown]
# ### Read the given dataset cropdata.csv (download from https://github.com/lakhdive-rmc)
# ### Drop the rows with missing values, if any

# %% [markdown]
# ### Import Libraries

# %% [markdown]
# ### Load & Understand the Dataset

# %% [markdown]
# ### Q1 : Which crops are produced during the Summer season?

# %% [markdown]
# ### Q2 : During which year did Haryana have the highest crop production?

# %% [markdown]
# ### Q3 : The maximum and minimum area for production were in the years?

# %% [markdown]
# ### Q 4 : Which state in India had the second lowest crop production? (overall, for all years)

# %% [markdown]
# ### Q 5 : What were the top three produced crops in the year 2012?

# %% [markdown]
# ### Q 6 : What is the standard deviation for Area of production?

# %% [markdown]
# ### Q 7 : Which is the crop that gave the highest production to the state of Andhra Pradesh?

# %% [markdown]
# ### Q 8 : What is the mean for the area of production?

# %% [markdown]
# ### Q 9 : What is the correlation coefficient between Area and Production?

# %% [markdown]
# ### Q 10 : The crops that had the highest production (in the correct order) were?

# %% [markdown]
# ### Q 11 : Which is the only crop that has the highest production during autumn, summer, and winter?
